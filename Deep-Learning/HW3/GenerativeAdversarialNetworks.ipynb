# %% [markdown]
# # GAN
#
# In this section you are required to implement vanilla GAN. The general structure for GAN is given below. You can use it as a template.
#
# Generative Adversarial Networks are used for learning distribution of data by playing a game between two networks which are generator and discriminator.
#
# There are couple of studies you can examine before implementing the model.
#
# Generative Adversarial Networks: https://arxiv.org/abs/1406.2661
#
# Unsupervised Representation Learning with Deep Convolutional Generative Adversarial Networks: https://arxiv.org/abs/1511.06434

# %% [markdown]
# **Link of the latest trained model= https://drive.google.com/open?id=1gaDp0qYBfa-A2g6jPB0jrqDkGHTKGxhY **

# %% [markdown]
# # Environment setup
# Follow the tutorial about how to utilize Google Colab but **don't install PyTorch** as mentioned in the blog post.
#
# Turkish:
# https://medium.com/deep-learning-turkiye/google-colab-ile-%C3%BCcretsiz-gpu-kullan%C4%B1m%C4%B1-30fdb7dd822e
#
# English:
# https://medium.com/deep-learning-turkey/google-colab-free-gpu-tutorial-e113627b9f5d

# %%
# !nvidia-smi
# This command should return some information about the GPU status if the runtime is right. 
# In addition to that, if you encounter memory issues, you can diagnose your model by this command.
# Out:
# Thu Dec 12 02:56:25 2019
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 418.56       Driver Version: 418.56       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  GeForce GTX TIT...  Off  | 00000000:01:00.0  On |                  N/A |
# | 36%   67C    P8    18W / 250W |     96MiB / 12209MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |    0      1046      G   /usr/lib/xorg/Xorg                            13MiB |
# |    0     24497      G   /usr/lib/xorg/Xorg                            79MiB |
# +-----------------------------------------------------------------------------+

# %%
import torch
from torch import nn, optim
from torchvision import transforms, datasets
from torch.utils.data import DataLoader, Dataset
import os
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
# %matplotlib inline

# %% [markdown]
# # Load the Logo data as instructed below

# %%
class logoLoader(Dataset):
    def __init__(self, path, transform=None):
      d_array = []
      self.transform = transform
      for i in range(5):
        root = os.path.join(path, 'LLD-icon_data_{}.pkl'.format(i))
        data = np.load(root, encoding='latin1',allow_pickle=True)
        d_array.append(data)
      
      self.data = np.concatenate((d_array[0],d_array[1],d_array[2],d_array[3],d_array[4]))
      print(self.data.shape)      
      
    # This method should be overrided in order to access the inside of dataset
    def __getitem__(self, ix):
        data_item = self.data[ix]
        # Load image
        data = Image.fromarray(data_item)
        if self.transform:
            data = self.transform(data)
        return data
      
    # This method should be overrided in order to make it work along with DataLoader class
    def __len__(self):
        return len(self.data)

# %%
transform = transforms.Compose([
                    transforms.ToTensor(),
                    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])
dataset = logoLoader(path='icondataset',transform=transform)
data_loader = DataLoader(dataset=dataset, batch_size=128 , num_workers=8, shuffle=True)
# Out:
# (486377, 32, 32, 3)

# %%
import torchvision
# Lets see some examples
loader=iter(data_loader)
img=next(loader)
grid = torchvision.utils.make_grid(img)
npimg = grid.numpy()
plt.imshow(np.transpose(npimg, (1,2,0)), interpolation='nearest')
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# # Implement the Discriminator Architecture of your Design
#
# Use Conv2d, Linear and Activation Layers to design a Discriminator
#
# Please note: Pay attention to whether Sigmoid Unit at the last layer is added in the Architecture OR in the Loss function, because in implementations of some loss functions in Pytorch, sigmoid unit is included by default. In this notebook we use BCELoss (given default) so you should add sigmoid to last layer.

# %%
latent_space_dim = 512
discriminator_filter_size = 64
generator_filter_size = 64

# My GAN network is similar to the DCGAN one of the earliest convolutional GAN architectures
# But in my GAN network latent space dimension is bigger than the DCGAN which empowers the model
# by containing more information as a latent space.
# Training process of the discriminator and generator considers the points that DCGAN authors defined.

# DC Gan proposes weight initialization from 0.02 Gaussian distribution
def weights_init(m):
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:
        m.weight.data.normal_(0.0, 0.02)
    elif classname.find('BatchNorm') != -1:
        m.weight.data.normal_(1.0, 0.02)
        m.bias.data.fill_(0)

# %%
class Discriminator(torch.nn.Module):
    """
    Implement discriminator network
    """
    def __init__(self):
        """
        Implement architecture
        """
        super(Discriminator, self).__init__()
        self.main = nn.Sequential(
            nn.Conv2d(3, discriminator_filter_size, 4, 2, 1, bias=False),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Conv2d(discriminator_filter_size, discriminator_filter_size * 2, 4, 2, 1, bias=False),
            nn.BatchNorm2d(discriminator_filter_size * 2),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Conv2d(discriminator_filter_size * 2, discriminator_filter_size * 4, 4, 2, 1, bias=False),
            nn.BatchNorm2d(discriminator_filter_size * 4),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Conv2d(discriminator_filter_size * 4, discriminator_filter_size * 8, 4, 2, 1, bias=False),
            nn.BatchNorm2d(discriminator_filter_size * 8),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Conv2d(discriminator_filter_size * 8, 1, 2, 1, 0, bias=False),
            nn.Sigmoid()
        )        
        
    def forward(self, x):
        """
        Implement forward-pass
        """
        x = self.main(x)
        
        return x

# %%
discriminator = Discriminator()
# As DC GAN paper propose we initialize weights from small gaussian distribution
discriminator.apply(weights_init)
discriminator = discriminator.cuda()

# %% [markdown]
# # Implement the Generator Architecture of your Design
#
# You can use (Upsample, Conv2d) pair or ConvTranspose2d and Activation Layers to design a Generator. Add Tanh to last layer for better training.

# %%
class Generator(torch.nn.Module):
    """
    Implement Generator Network
    """
    def __init__(self):
        """
        Implement architecture
        """
        super(Generator, self).__init__()
        self.main = nn.Sequential(
            nn.ConvTranspose2d( latent_space_dim, generator_filter_size * 8, 4, 1, 0, bias=False),
            nn.BatchNorm2d(generator_filter_size * 8),
            nn.ReLU(True),
            nn.ConvTranspose2d(generator_filter_size * 8, generator_filter_size * 4, 4, 2, 1, bias=False),
            nn.BatchNorm2d(generator_filter_size * 4),
            nn.ReLU(True),
            nn.ConvTranspose2d(generator_filter_size * 4, generator_filter_size * 2, 4, 2, 1, bias=False),
            nn.BatchNorm2d(generator_filter_size * 2),
            nn.ReLU(True),
            nn.ConvTranspose2d(generator_filter_size * 2, 3, 4, 2, 1, bias=False),
            nn.Tanh()
        )
        
        
    def forward(self, x):
        """
        Implement forward-pass
        """
        x = self.main(x)
        return x

# %%
generator = Generator()
generator.apply(weights_init)
generator = generator.cuda()

# %% [markdown]
# # Initialization of the Optimizer: You can change the Parameters according to your needs

# %%
disc_optimizer = optim.Adam(discriminator.parameters(), lr=1e-3, betas = [0.5,0.999])
gen_optimizer = optim.Adam(generator.parameters(), lr=1e-3, betas = [0.5,0.999])

# %% [markdown]
# # VanillaGAN uses Binary Cross Entropy loss, instatiated below.

# %%
loss = nn.BCELoss()
fixed_noise = torch.randn(128, latent_space_dim, 1, 1).cuda()
real_label = 1
fake_label = 0

# %% [markdown]
# # Implement training loop

# %%
num_epochs = 6
losses_iter_discriminator = []
losses_epoch_discriminator = []
losses_iter_generator = []
losses_epoch_generator = []
generator.train()
discriminator.train()
for epoch in range(num_epochs):
    count = 0
    for n_batch, (real_batch) in enumerate(data_loader):
        
        disc_optimizer.zero_grad()
        real_batch = real_batch.cuda()
        batch_size = real_batch.size(0)
        label = torch.full((batch_size,1,1,1), real_label).cuda()
        output = discriminator(real_batch)
        disc_real_error = loss(output, label)
        disc_real_error.backward()

        # train with fake
        noise = torch.randn(batch_size, latent_space_dim, 1, 1).cuda()
        fake = generator(noise)
        label.fill_(fake_label)
        output = discriminator(fake.detach())
        disc_real_fake = loss(output, label)
        disc_real_fake.backward()
        d_error = disc_real_error + disc_real_fake
        losses_iter_discriminator.append(d_error.item())
        disc_optimizer.step()

        # Update the Generator
        
        generator.zero_grad()
        # Fake labels are real for generator
        label.fill_(real_label)  
        # Discriminate the  fake images
        output = discriminator(fake)
        g_error = loss(output, label)
        losses_iter_generator.append(g_error.item())
        #Update adversarial loss
        g_error.backward()
        
        gen_optimizer.step()
        # Call Discriminator Training function with appropriate parameters
        
        # Call Generator Training function with appropriate parameters
        
        if (n_batch + 1) % 100 == 0:
            print("epoch: {%d}, batch number: {%d}, d_error: {%.4f}, g_error: {%.4f}" % 
                  (epoch + 1, n_batch + 1, d_error.item(), g_error.item()))
            
    losses_epoch_discriminator.append(np.mean(losses_iter_discriminator[-count:]))
    losses_epoch_generator.append(np.mean(losses_iter_generator[-count:]))
# Out:
# epoch: {1}, batch number: {100}, d_error: {0.4595}, g_error: {2.5619}
# epoch: {1}, batch number: {200}, d_error: {0.5987}, g_error: {2.7224}
# epoch: {1}, batch number: {300}, d_error: {0.9717}, g_error: {5.3952}
# epoch: {1}, batch number: {400}, d_error: {1.1355}, g_error: {2.8350}
# epoch: {1}, batch number: {500}, d_error: {0.8403}, g_error: {3.3518}
# epoch: {1}, batch number: {600}, d_error: {0.8378}, g_error: {3.8152}
# epoch: {1}, batch number: {700}, d_error: {0.4442}, g_error: {2.7850}
# epoch: {1}, batch number: {800}, d_error: {1.2491}, g_error: {5.0412}
# epoch: {1}, batch number: {900}, d_error: {1.4146}, g_error: {5.8818}
# epoch: {1}, batch number: {1000}, d_error: {1.3219}, g_error: {1.4648}
# epoch: {1}, batch number: {1100}, d_error: {0.6077}, g_error: {2.7931}
# epoch: {1}, batch number: {1200}, d_error: {0.7308}, g_error: {2.4835}
# epoch: {1}, batch number: {1300}, d_error: {1.3523}, g_error: {3.0820}
# epoch: {1}, batch number: {1400}, d_error: {0.8328}, g_error: {4.1202}
# epoch: {1}, batch number: {1500}, d_error: {0.5706}, g_error: {2.2108}
# epoch: {1}, batch number: {1600}, d_error: {0.4838}, g_error: {4.4649}
# epoch: {1}, batch number: {1700}, d_error: {0.7862}, g_error: {0.9124}
# epoch: {1}, batch number: {1800}, d_error: {0.6304}, g_error: {2.1768}
# epoch: {1}, batch number: {1900}, d_error: {0.3299}, g_error: {2.7973}
# epoch: {1}, batch number: {2000}, d_error: {0.1877}, g_error: {5.4890}
# epoch: {1}, batch number: {2100}, d_error: {0.3784}, g_error: {2.9667}
# epoch: {1}, batch number: {2200}, d_error: {0.5322}, g_error: {6.6454}
# epoch: {1}, batch number: {2300}, d_error: {0.6285}, g_error: {5.2403}
# epoch: {1}, batch number: {2400}, d_error: {0.3846}, g_error: {3.5542}
# epoch: {1}, batch number: {2500}, d_error: {0.9919}, g_error: {7.8951}
# epoch: {1}, batch number: {2600}, d_error: {2.5892}, g_error: {10.5817}
# epoch: {1}, batch number: {2700}, d_error: {0.0361}, g_error: {4.1081}
# epoch: {1}, batch number: {2800}, d_error: {0.5908}, g_error: {4.0611}
# epoch: {1}, batch number: {2900}, d_error: {0.1787}, g_error: {4.0431}
# epoch: {1}, batch number: {3000}, d_error: {0.2229}, g_error: {4.3583}
# epoch: {1}, batch number: {3100}, d_error: {0.0527}, g_error: {4.1804}
# epoch: {1}, batch number: {3200}, d_error: {0.2294}, g_error: {2.3907}
# epoch: {1}, batch number: {3300}, d_error: {0.7779}, g_error: {0.3568}
# epoch: {1}, batch number: {3400}, d_error: {0.1486}, g_error: {4.4496}
# epoch: {1}, batch number: {3500}, d_error: {0.0394}, g_error: {4.7743}
# epoch: {1}, batch number: {3600}, d_error: {0.2360}, g_error: {2.5653}
# epoch: {1}, batch number: {3700}, d_error: {0.0954}, g_error: {3.3347}
# epoch: {1}, batch number: {3800}, d_error: {0.7451}, g_error: {1.7989}
# epoch: {2}, batch number: {100}, d_error: {0.6146}, g_error: {2.4192}
# epoch: {2}, batch number: {200}, d_error: {0.0699}, g_error: {4.3709}
# epoch: {2}, batch number: {300}, d_error: {2.8661}, g_error: {1.2489}
# epoch: {2}, batch number: {400}, d_error: {0.2067}, g_error: {2.6329}
# epoch: {2}, batch number: {500}, d_error: {0.1114}, g_error: {4.6883}
# epoch: {2}, batch number: {600}, d_error: {0.0204}, g_error: {5.3216}
# epoch: {2}, batch number: {700}, d_error: {0.7761}, g_error: {7.3058}
# epoch: {2}, batch number: {800}, d_error: {1.4047}, g_error: {2.2164}
# epoch: {2}, batch number: {900}, d_error: {0.0669}, g_error: {4.1337}
# epoch: {2}, batch number: {1000}, d_error: {0.0985}, g_error: {4.2275}
# epoch: {2}, batch number: {1100}, d_error: {0.0380}, g_error: {5.5660}
# epoch: {2}, batch number: {1200}, d_error: {0.7605}, g_error: {16.3861}
# epoch: {2}, batch number: {1300}, d_error: {1.5722}, g_error: {6.6606}
# epoch: {2}, batch number: {1400}, d_error: {0.0523}, g_error: {4.3732}
# epoch: {2}, batch number: {1500}, d_error: {0.3773}, g_error: {5.2780}
# epoch: {2}, batch number: {1600}, d_error: {0.0774}, g_error: {4.3385}
# epoch: {2}, batch number: {1700}, d_error: {0.0347}, g_error: {5.0629}
# epoch: {2}, batch number: {1800}, d_error: {0.2459}, g_error: {4.6141}
# epoch: {2}, batch number: {1900}, d_error: {4.6987}, g_error: {8.6257}
# epoch: {2}, batch number: {2000}, d_error: {0.1208}, g_error: {3.5195}
# epoch: {2}, batch number: {2100}, d_error: {0.3119}, g_error: {2.6347}
# epoch: {2}, batch number: {2200}, d_error: {4.8331}, g_error: {11.3204}
# epoch: {2}, batch number: {2300}, d_error: {0.0463}, g_error: {4.5901}
# epoch: {2}, batch number: {2400}, d_error: {0.0153}, g_error: {5.5198}
# epoch: {2}, batch number: {2500}, d_error: {0.0412}, g_error: {4.6565}
# epoch: {2}, batch number: {2600}, d_error: {0.4390}, g_error: {7.7758}
# epoch: {2}, batch number: {2700}, d_error: {0.0745}, g_error: {3.8358}
# epoch: {2}, batch number: {2800}, d_error: {0.9991}, g_error: {9.0565}
# epoch: {2}, batch number: {2900}, d_error: {0.3128}, g_error: {6.0906}
# epoch: {2}, batch number: {3000}, d_error: {0.0630}, g_error: {3.6528}
# epoch: {2}, batch number: {3100}, d_error: {0.0493}, g_error: {4.2568}
# epoch: {2}, batch number: {3200}, d_error: {0.0195}, g_error: {4.9315}
# epoch: {2}, batch number: {3300}, d_error: {10.4596}, g_error: {3.4407}
# epoch: {2}, batch number: {3400}, d_error: {0.0606}, g_error: {4.4198}
# epoch: {2}, batch number: {3500}, d_error: {0.4826}, g_error: {3.5924}
# epoch: {2}, batch number: {3600}, d_error: {0.4316}, g_error: {2.5869}
# epoch: {2}, batch number: {3700}, d_error: {0.2777}, g_error: {2.2159}
# epoch: {2}, batch number: {3800}, d_error: {0.0199}, g_error: {5.3336}
# epoch: {3}, batch number: {100}, d_error: {0.0296}, g_error: {5.6295}
# epoch: {3}, batch number: {200}, d_error: {0.0054}, g_error: {6.3908}
# epoch: {3}, batch number: {300}, d_error: {0.0141}, g_error: {5.5584}
# epoch: {3}, batch number: {400}, d_error: {0.0048}, g_error: {6.3954}
# epoch: {3}, batch number: {500}, d_error: {0.0025}, g_error: {7.6392}
# epoch: {3}, batch number: {600}, d_error: {0.0508}, g_error: {7.9615}
# epoch: {3}, batch number: {700}, d_error: {0.0669}, g_error: {4.8929}
# epoch: {3}, batch number: {800}, d_error: {0.0784}, g_error: {4.4837}
# epoch: {3}, batch number: {900}, d_error: {0.0998}, g_error: {4.0650}
# epoch: {3}, batch number: {1000}, d_error: {0.0194}, g_error: {5.7885}
# epoch: {3}, batch number: {1100}, d_error: {0.1009}, g_error: {5.3446}
# epoch: {3}, batch number: {1200}, d_error: {0.0416}, g_error: {5.4666}
# epoch: {3}, batch number: {1300}, d_error: {1.1700}, g_error: {1.4309}
# epoch: {3}, batch number: {1400}, d_error: {0.0197}, g_error: {4.9182}
# epoch: {3}, batch number: {1500}, d_error: {0.0304}, g_error: {4.8306}
# epoch: {3}, batch number: {1600}, d_error: {0.0162}, g_error: {8.3089}
# epoch: {3}, batch number: {1700}, d_error: {0.0046}, g_error: {6.6598}
# epoch: {3}, batch number: {1800}, d_error: {0.0058}, g_error: {6.7317}
# epoch: {3}, batch number: {1900}, d_error: {0.9624}, g_error: {3.4159}
# epoch: {3}, batch number: {2000}, d_error: {0.4300}, g_error: {4.9376}
# epoch: {3}, batch number: {2100}, d_error: {0.2043}, g_error: {2.2496}
# epoch: {3}, batch number: {2200}, d_error: {0.0288}, g_error: {5.6527}
# epoch: {3}, batch number: {2300}, d_error: {0.0469}, g_error: {4.7539}
# epoch: {3}, batch number: {2400}, d_error: {0.1237}, g_error: {2.8982}
# epoch: {3}, batch number: {2500}, d_error: {0.0325}, g_error: {5.9775}
# epoch: {3}, batch number: {2600}, d_error: {0.0494}, g_error: {4.5065}
# epoch: {3}, batch number: {2700}, d_error: {0.0163}, g_error: {5.3613}
# epoch: {3}, batch number: {2800}, d_error: {7.2295}, g_error: {1.6653}
# epoch: {3}, batch number: {2900}, d_error: {0.0254}, g_error: {4.8471}
# epoch: {3}, batch number: {3000}, d_error: {0.0303}, g_error: {5.8063}
# epoch: {3}, batch number: {3100}, d_error: {0.0094}, g_error: {6.1754}
# epoch: {3}, batch number: {3200}, d_error: {0.0916}, g_error: {4.0572}
# epoch: {3}, batch number: {3300}, d_error: {0.0305}, g_error: {4.2420}
# epoch: {3}, batch number: {3400}, d_error: {0.0908}, g_error: {5.0226}
# epoch: {3}, batch number: {3500}, d_error: {0.0561}, g_error: {5.0120}
# epoch: {3}, batch number: {3600}, d_error: {0.0237}, g_error: {5.7622}
# epoch: {3}, batch number: {3700}, d_error: {0.0101}, g_error: {5.6644}
# epoch: {3}, batch number: {3800}, d_error: {0.0442}, g_error: {4.3612}
# epoch: {4}, batch number: {100}, d_error: {0.0473}, g_error: {5.5739}
# epoch: {4}, batch number: {200}, d_error: {0.3002}, g_error: {5.8886}
# epoch: {4}, batch number: {300}, d_error: {0.0513}, g_error: {4.9595}
# epoch: {4}, batch number: {400}, d_error: {0.0360}, g_error: {5.3357}
# epoch: {4}, batch number: {500}, d_error: {0.0111}, g_error: {5.2332}
# epoch: {4}, batch number: {600}, d_error: {1.9961}, g_error: {0.9734}
# epoch: {4}, batch number: {700}, d_error: {0.0762}, g_error: {4.1856}
# epoch: {4}, batch number: {800}, d_error: {1.1803}, g_error: {1.1383}
# epoch: {4}, batch number: {900}, d_error: {0.0259}, g_error: {5.6196}
# epoch: {4}, batch number: {1000}, d_error: {0.0276}, g_error: {4.9467}
# epoch: {4}, batch number: {1100}, d_error: {0.0074}, g_error: {7.0914}
# epoch: {4}, batch number: {1200}, d_error: {0.0121}, g_error: {5.9413}
# epoch: {4}, batch number: {1300}, d_error: {0.0107}, g_error: {5.5409}
# epoch: {4}, batch number: {1400}, d_error: {0.0806}, g_error: {3.5303}
# epoch: {4}, batch number: {1500}, d_error: {0.3290}, g_error: {2.0379}
# epoch: {4}, batch number: {1600}, d_error: {0.0140}, g_error: {6.6766}
# epoch: {4}, batch number: {1700}, d_error: {0.0079}, g_error: {6.7037}
# epoch: {4}, batch number: {1800}, d_error: {0.3479}, g_error: {5.5965}
# epoch: {4}, batch number: {1900}, d_error: {0.0163}, g_error: {5.8195}
# epoch: {4}, batch number: {2000}, d_error: {0.0180}, g_error: {5.5828}
# epoch: {4}, batch number: {2100}, d_error: {0.1677}, g_error: {5.6680}
# epoch: {4}, batch number: {2200}, d_error: {0.0267}, g_error: {5.0405}
# epoch: {4}, batch number: {2300}, d_error: {0.0356}, g_error: {6.0898}
# epoch: {4}, batch number: {2400}, d_error: {0.0252}, g_error: {4.5779}
# epoch: {4}, batch number: {2500}, d_error: {0.0047}, g_error: {6.0192}
# epoch: {4}, batch number: {2600}, d_error: {0.0497}, g_error: {4.8639}
# epoch: {4}, batch number: {2700}, d_error: {0.0040}, g_error: {7.0619}
# epoch: {4}, batch number: {2800}, d_error: {0.0266}, g_error: {5.4938}
# epoch: {4}, batch number: {2900}, d_error: {0.0080}, g_error: {6.0337}
# epoch: {4}, batch number: {3000}, d_error: {0.0144}, g_error: {6.0851}
# epoch: {4}, batch number: {3100}, d_error: {1.4219}, g_error: {1.4676}
# epoch: {4}, batch number: {3200}, d_error: {0.3042}, g_error: {2.9563}
# epoch: {4}, batch number: {3300}, d_error: {0.0063}, g_error: {6.0442}
# epoch: {4}, batch number: {3400}, d_error: {4.8390}, g_error: {5.6705}
# epoch: {4}, batch number: {3500}, d_error: {0.0517}, g_error: {6.7808}
# epoch: {4}, batch number: {3600}, d_error: {0.1175}, g_error: {4.5987}
# epoch: {4}, batch number: {3700}, d_error: {0.0183}, g_error: {5.5643}
# epoch: {4}, batch number: {3800}, d_error: {0.0485}, g_error: {4.7842}
# epoch: {5}, batch number: {100}, d_error: {0.0355}, g_error: {4.9059}
# epoch: {5}, batch number: {200}, d_error: {0.0294}, g_error: {5.1662}
# epoch: {5}, batch number: {300}, d_error: {0.0109}, g_error: {5.7689}
# epoch: {5}, batch number: {400}, d_error: {0.0099}, g_error: {6.1688}
# epoch: {5}, batch number: {500}, d_error: {0.0542}, g_error: {7.2554}
# epoch: {5}, batch number: {600}, d_error: {0.1324}, g_error: {5.4588}
# epoch: {5}, batch number: {700}, d_error: {0.0431}, g_error: {4.6517}
# epoch: {5}, batch number: {800}, d_error: {0.0205}, g_error: {5.2807}
# epoch: {5}, batch number: {900}, d_error: {0.2430}, g_error: {6.0011}
# epoch: {5}, batch number: {1000}, d_error: {0.0106}, g_error: {5.6552}
# epoch: {5}, batch number: {1100}, d_error: {0.1610}, g_error: {4.6027}
# epoch: {5}, batch number: {1200}, d_error: {0.2021}, g_error: {5.5670}
# epoch: {5}, batch number: {1300}, d_error: {0.0267}, g_error: {5.0477}
# epoch: {5}, batch number: {1400}, d_error: {0.0183}, g_error: {6.1463}
# epoch: {5}, batch number: {1500}, d_error: {0.0491}, g_error: {4.6058}
# epoch: {5}, batch number: {1600}, d_error: {0.0025}, g_error: {7.2492}
# epoch: {5}, batch number: {1700}, d_error: {0.0569}, g_error: {3.3213}
# epoch: {5}, batch number: {1800}, d_error: {0.0046}, g_error: {6.8051}
# epoch: {5}, batch number: {1900}, d_error: {0.0020}, g_error: {7.4080}
# epoch: {5}, batch number: {2000}, d_error: {0.0019}, g_error: {7.5717}
# epoch: {5}, batch number: {2100}, d_error: {0.0578}, g_error: {5.9105}
# epoch: {5}, batch number: {2200}, d_error: {0.0980}, g_error: {5.5087}
# epoch: {5}, batch number: {2300}, d_error: {0.1028}, g_error: {4.8189}
# epoch: {5}, batch number: {2400}, d_error: {0.0130}, g_error: {6.5876}
# epoch: {5}, batch number: {2500}, d_error: {0.0098}, g_error: {5.4665}
# epoch: {5}, batch number: {2600}, d_error: {0.0088}, g_error: {6.0073}
# epoch: {5}, batch number: {2700}, d_error: {0.0290}, g_error: {4.8212}
# epoch: {5}, batch number: {2800}, d_error: {0.0062}, g_error: {6.7965}
# epoch: {5}, batch number: {2900}, d_error: {0.0289}, g_error: {4.6893}
# epoch: {5}, batch number: {3000}, d_error: {0.0348}, g_error: {5.1657}
# epoch: {5}, batch number: {3100}, d_error: {0.0090}, g_error: {6.2160}
# epoch: {5}, batch number: {3200}, d_error: {0.0232}, g_error: {5.9747}
# epoch: {5}, batch number: {3300}, d_error: {0.0189}, g_error: {6.2997}
# epoch: {5}, batch number: {3400}, d_error: {0.0080}, g_error: {6.5784}
# epoch: {5}, batch number: {3500}, d_error: {0.2695}, g_error: {9.3954}
# epoch: {5}, batch number: {3600}, d_error: {0.0675}, g_error: {4.7495}
# epoch: {5}, batch number: {3700}, d_error: {0.0072}, g_error: {7.1599}
# epoch: {5}, batch number: {3800}, d_error: {0.0084}, g_error: {5.4104}
# epoch: {6}, batch number: {100}, d_error: {0.0085}, g_error: {7.4319}
# epoch: {6}, batch number: {200}, d_error: {0.4607}, g_error: {1.2955}
# epoch: {6}, batch number: {300}, d_error: {0.0328}, g_error: {5.0757}
# epoch: {6}, batch number: {400}, d_error: {0.1574}, g_error: {5.3064}
# epoch: {6}, batch number: {500}, d_error: {0.0573}, g_error: {4.5318}
# epoch: {6}, batch number: {600}, d_error: {0.0097}, g_error: {5.1927}
# epoch: {6}, batch number: {700}, d_error: {0.0574}, g_error: {5.0745}
# epoch: {6}, batch number: {800}, d_error: {0.0128}, g_error: {5.7107}
# epoch: {6}, batch number: {900}, d_error: {0.0398}, g_error: {3.0454}
# epoch: {6}, batch number: {1000}, d_error: {0.0191}, g_error: {6.6667}
# epoch: {6}, batch number: {1100}, d_error: {0.0077}, g_error: {6.3904}
# epoch: {6}, batch number: {1200}, d_error: {0.0017}, g_error: {7.6687}
# epoch: {6}, batch number: {1300}, d_error: {0.0194}, g_error: {6.5931}
# epoch: {6}, batch number: {1400}, d_error: {0.0015}, g_error: {8.7098}
# epoch: {6}, batch number: {1500}, d_error: {0.0058}, g_error: {6.2634}
# epoch: {6}, batch number: {1600}, d_error: {0.0114}, g_error: {6.7163}
# epoch: {6}, batch number: {1700}, d_error: {0.0145}, g_error: {5.5916}
# epoch: {6}, batch number: {1800}, d_error: {0.2169}, g_error: {3.0633}
# epoch: {6}, batch number: {1900}, d_error: {0.0200}, g_error: {6.7929}
# epoch: {6}, batch number: {2000}, d_error: {1.0283}, g_error: {11.4378}
# epoch: {6}, batch number: {2100}, d_error: {0.0097}, g_error: {5.8246}
# epoch: {6}, batch number: {2200}, d_error: {0.1353}, g_error: {3.4972}
# epoch: {6}, batch number: {2300}, d_error: {0.0039}, g_error: {5.6581}
# epoch: {6}, batch number: {2400}, d_error: {0.0889}, g_error: {5.9752}
# epoch: {6}, batch number: {2500}, d_error: {0.0111}, g_error: {5.8298}
# epoch: {6}, batch number: {2600}, d_error: {0.0086}, g_error: {5.9640}
# epoch: {6}, batch number: {2700}, d_error: {0.0057}, g_error: {6.4656}
# epoch: {6}, batch number: {2800}, d_error: {2.7521}, g_error: {19.0893}
# epoch: {6}, batch number: {2900}, d_error: {0.0162}, g_error: {6.0735}
# epoch: {6}, batch number: {3000}, d_error: {0.0051}, g_error: {6.2345}
# epoch: {6}, batch number: {3100}, d_error: {0.9038}, g_error: {4.8286}
# epoch: {6}, batch number: {3200}, d_error: {0.0234}, g_error: {5.0278}
# epoch: {6}, batch number: {3300}, d_error: {0.2557}, g_error: {5.6095}
# epoch: {6}, batch number: {3400}, d_error: {0.0137}, g_error: {7.4132}
# epoch: {6}, batch number: {3500}, d_error: {0.0081}, g_error: {6.2488}
# epoch: {6}, batch number: {3600}, d_error: {0.0108}, g_error: {6.0560}
# epoch: {6}, batch number: {3700}, d_error: {0.0063}, g_error: {6.4847}
# epoch: {6}, batch number: {3800}, d_error: {0.3019}, g_error: {8.8785}

# %% [markdown]
# ## Report the training loss curves and test results (generated images) vanillaGAN. Also briefly discuss the results.

# %%
import torchvision.utils as vutils
generator.eval()
noise = torch.randn(batch_size, latent_space_dim, 1, 1).cuda()


fake = generator(noise)
from IPython.display import Image
from IPython.core.display import Image, display

plt.figure()
fake = fake.cpu().detach()
plt.figure(figsize=(10,10))
batch_output_grid = torchvision.utils.make_grid(fake[:16]).numpy()
plt.imshow(np.transpose(batch_output_grid, (1, 2, 0)))
plt.title('Reconstructed images from random noise')
plt.show()

noise = torch.randn(batch_size, latent_space_dim, 1, 1).cuda()
fake = generator(noise)
plt.figure()
fake = fake.cpu().detach()
plt.figure(figsize=(10,10))
batch_output_grid = torchvision.utils.make_grid(fake[:16]).numpy()
plt.imshow(np.transpose(batch_output_grid, (1, 2, 0)))
plt.title('Reconstructed images from another random noise')
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# **As you can see there are some good images that can be a logo for example dog in front of circle. Also model generates lots of vivid colors. But in overall the structures are not meaningfull and therefore it may be best to increase the impact of the BCE loss rather than adversarial loss. However In general within a short time it generates a few good logos.**
#
# **Loss curves don't say much about the training process but it is easy to see that as discriminator loss increase the generator loss first increase then decrease.**

# %%
# Plot Generator Loss
plt.figure()
plt.plot([i+1 for i in range(len(losses_iter_generator))],losses_iter_generator)
plt.xlabel("Iterations")
plt.ylabel("Losses")
plt.show()

# %%
# Plot Discriminator Loss
plt.figure()
plt.plot([i+1 for i in range(len(losses_iter_discriminator))],losses_iter_discriminator)
plt.xlabel("Iterations")
plt.ylabel("Losses")
plt.show()

# %% [markdown]
# #### After you have completed the training, save your generator model using the following command
# **Link of the latest trained model= https://drive.google.com/open?id=1gaDp0qYBfa-A2g6jPB0jrqDkGHTKGxhY **

# %%
student_id = 504191504
torch.save(generator.state_dict(),'drive/My Drive/blg561/{}_GAN.pth'.format(student_id))
